# %%
# !pip install pymahjong
# Out:
# Collecting pymahjong
#   Downloading pymahjong-1.0.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_31_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pymahjong) (2.0.2)
# Requirement already satisfied: gym<=0.26.2 in /usr/local/lib/python3.11/dist-packages (from pymahjong) (0.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym<=0.26.2->pymahjong) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym<=0.26.2->pymahjong) (0.0.8)
# Downloading pymahjong-1.0.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_31_x86_64.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.5/413.5 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: pymahjong
# Successfully installed pymahjong-1.0.4

# %%
# Section 1: Setup
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import os
from pymahjong import MahjongEnv

torch.manual_seed(42)
np.random.seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

OBS_CHANNELS = 93
HEIGHT = 34
WIDTH = 1
NUM_ACTIONS = 136

# %%
def encode_game_state(obs):
    """
    Converts pymahjong (93, 34) obs into CNN input format: (1, 93, 34, 1)
    """
    obs = np.array(obs, dtype=np.float32)  # (93, 34)
    return torch.tensor(obs).unsqueeze(0).unsqueeze(-1).to(device)  # (1, 93, 34, 1)

# %%
class MahjongCNNBase(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(OBS_CHANNELS, 64, kernel_size=(3, 1), padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=(3, 1), padding=0),
            nn.ReLU(),
            nn.Flatten()
        )
        self.output_dim = self._get_output_dim()

    def _get_output_dim(self):
        dummy = torch.zeros((1, OBS_CHANNELS, HEIGHT, WIDTH))
        return self.conv(dummy).shape[1]

    def forward(self, x):
        return self.conv(x)

class DiscreteHead(nn.Module):
    def __init__(self, base, output_size):
        super().__init__()
        self.base = base
        self.head = nn.Sequential(
            nn.Linear(base.output_dim, 256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )

    def forward(self, x):
        return self.head(self.base(x))

# %%
class TrainingBot:
    def __init__(self, pid, models, logs):
        self.pid = pid
        self.models = models
        self.logs = logs

    def act(self, obs, valid_actions, reward=0.0):
        state = encode_game_state(obs)  # shape: (1, 93, 34, 1)
        logits = self.models["action"](state)  # shape: (1, N) where N = model output (e.g. 136)
        logits = logits.squeeze(0)

        # Only use logits for valid actions
        valid_logits = logits[valid_actions]
        probs = F.softmax(valid_logits, dim=0).detach().cpu().numpy()
        action_index = np.random.choice(len(valid_actions), p=probs)
        action = valid_actions[action_index]

        self.logs.append((state.squeeze(0), action, reward))
        return action

# %%
def train_pg(model, optimizer, log_data, normalize_advantage=True, reward_scale=1.0):
    """
    Train a policy using REINFORCE with optional reward scaling and advantage normalization.

    Parameters:
        model: policy model outputting logits over actions
        optimizer: optimizer for the model
        log_data: list of (state, action, reward)
        normalize_advantage: if True, normalize the reward signal to mean=0, std=1
        reward_scale: scale the reward signal to prevent exploding loss
    """
    if not log_data:
        return 0.0

    states, actions, rewards = zip(*log_data)
    states = torch.stack(states).to(device)
    actions = torch.tensor(actions, dtype=torch.long).to(device)
    rewards = torch.tensor(rewards, dtype=torch.float32).to(device)

    # 🧠 Scale reward down to avoid huge loss values
    rewards *= reward_scale

    # 🎯 Use advantage = reward (baseline = 0 for now)
    advantages = rewards.clone()

    if normalize_advantage:
        mean = advantages.mean()
        std = advantages.std()
        if std > 1e-5:
            advantages = (advantages - mean) / (std + 1e-8)
        else:
            advantages = advantages - mean

    # 🔁 Forward pass
    logits = model(states)
    log_probs = F.log_softmax(logits, dim=1)
    selected_log_probs = log_probs[torch.arange(len(actions)), actions]

    # 🎯 Policy gradient loss
    loss = -(advantages * selected_log_probs).mean()

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # 🔎 Debug: print stats
    print(f"Loss: {loss.item():.4f}, Reward mean: {rewards.mean().item():.2f}, Std: {rewards.std().item():.2f}")

    return loss.item()

# %%
def simulate_hanchan(bots, gamma=1.0, placement_bonus={1: 90, 2: 45, 3: 0, 4: -150}):
    from pymahjong import MahjongEnv
    import numpy as np

    env = MahjongEnv()
    logs = []
    scores = [25000, 25000, 25000, 25000]
    oya = 0
    kyoutaku = 0
    honba = 0
    wind_order = ["east", "south"]

    def determine_next_oya(current_oya, winner_id, tenpai, is_draw):
        if not is_draw and winner_id == current_oya:
            return current_oya, True
        if is_draw and tenpai[current_oya]:
            return current_oya, True
        return (current_oya + 1) % 4, False

    def get_player_placement(scores, oya):
        """
        Returns 1-based rank of player 0 using score and Tenhou-style clockwise tiebreaking.
        """
        def oya_tiebreak_key(pid): return (pid - oya) % 4
        player_scores = [(score, pid) for pid, score in enumerate(scores)]
        sorted_players = sorted(player_scores, key=lambda x: (-x[0], oya_tiebreak_key(x[1])))
        for rank, (_, pid) in enumerate(sorted_players, start=1):
            if pid == 0:
                return rank

    busted = False

    for wind in wind_order:
        for round_index in range(4):
            consecutive_oya = 0
            while consecutive_oya < 4:
                env.reset(
                    oya=oya,
                    game_wind=wind,
                    scores=scores,
                    kyoutaku=kyoutaku,
                    honba=honba
                )

                hand_logs = []
                step_index = 0
                while not env.is_over():
                    pid = env.get_curr_player_id()
                    obs = env.get_obs(pid)
                    valid = env.get_valid_actions()
                    reward = 0

                    action = bots[pid].act(obs, valid, reward)
                    env.step(pid, action)

                    if pid == 0:
                        hand_logs.append((encode_game_state(obs).squeeze(0), action, reward))
                    step_index += 1

                payoffs = env.get_payoffs()
                scores = list(np.array(scores) + np.array(payoffs))
                scores = [int(s) for s in scores]

                # 💥 Bust-out check
                if any(score < 0 for score in scores):
                    busted = True
                    break

                # Discounted reward shaping
                for i in range(len(hand_logs)):
                    s, a, r = hand_logs[i]
                    r += payoffs[0] * (gamma ** i)
                    hand_logs[i] = (s, a, r)
                logs += hand_logs

                # Next hand setup
                try:
                    winner = env.t.winner_id
                except:
                    winner = -1
                try:
                    tenpai = env.t.tenpais
                except:
                    tenpai = [False] * 4

                oya_next, oya_continues = determine_next_oya(oya, winner, tenpai, winner == -1)
                if oya_next == oya:
                    honba += 1
                else:
                    honba = 0
                    oya = oya_next
                    consecutive_oya += 1

            if busted:
                break
        if busted:
            break

    # 🎯 Final placement bonus (Tenhou style + oya tiebreaker)
    placement = get_player_placement(scores, oya)
    bonus = placement_bonus[placement]
    logs = [(s, a, r + bonus) for (s, a, r) in logs]

    return logs

# %%
# Init model + optimizer
base = MahjongCNNBase().to(device)
models = {
    "action": DiscreteHead(base, NUM_ACTIONS).to(device)
}
optimizers = {
    name: torch.optim.Adam(models[name].parameters(), lr=1e-4)
    for name in models
}

NUM_EPISODES = 10000
SAVE_EVERY = 100

for episode in range(1, NUM_EPISODES + 1):
    env = MahjongEnv()
    env.reset()
    logs = []

    bots = [
        TrainingBot(pid, models, logs if pid == 0 else [])
        for pid in range(4)
    ]
    logs = simulate_hanchan(bots, gamma=1.0)
    loss = train_pg(models["action"], optimizers["action"], logs)
    # while not env.is_over():
    #     pid = env.get_curr_player_id()
    #     obs = env.get_obs(pid)
    #     valid = env.get_valid_actions()
    #     action = bots[pid].act(obs, valid)
    #     env.step(pid, action)

    # # Get final reward for REINFORCE
    # payoffs = env.get_payoffs()  # [p0, p1, p2, p3]
    # for i in range(len(logs)):
    #     state, action, _ = logs[i]
    #     logs[i] = (state, action, payoffs[0])

    # Train
    # loss = train_pg(models["action"], optimizers["action"], logs)
    print(f"[Episode {episode}] | Loss: {loss:.4f}")

    if episode % SAVE_EVERY == 0:
        os.makedirs(f"checkpoints/ep_{episode}", exist_ok=True)
        torch.save(models["action"].state_dict(), f"checkpoints/ep_{episode}/action.pt")
        print(f"✓ Model saved at ep {episode}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [Episode 1217] | Loss: -0.0028
# Loss: -0.0039, Reward mean: -2444.87, Std: 2688.61
# [Episode 1218] | Loss: -0.0039
# Loss: -0.0038, Reward mean: 573.61, Std: 1193.62
# [Episode 1219] | Loss: -0.0038
# Loss: -0.0138, Reward mean: 4986.86, Std: 7386.57
# [Episode 1220] | Loss: -0.0138
# Loss: 0.0082, Reward mean: -1790.18, Std: 2778.15
# [Episode 1221] | Loss: 0.0082
# Loss: -0.0057, Reward mean: -1549.48, Std: 3010.40
# [Episode 1222] | Loss: -0.0057
# Loss: 0.0114, Reward mean: 7673.85, Std: 9192.09
# [Episode 1223] | Loss: 0.0114
# Loss: 0.0043, Reward mean: -159.57, Std: 366.86
# [Episode 1224] | Loss: 0.0043
# Loss: -0.0057, Reward mean: -3007.63, Std: 3129.26
# [Episode 1225] | Loss: -0.0057
# Loss: 0.0038, Reward mean: 2090.00, Std: 1261.51
# [Episode 1226] | Loss: 0.0038
# Loss: -0.0026, Reward mean: -2864.52, Std: 3351.83
# [Episode 1227] | Loss: -0.0026
# Loss: 0.0164, Reward mean: -3449.15, Std: 2649.87
# [Episode 1228] | Loss: 0.0164
# Loss: -0.0174, Reward mean: -3059.33, Std: 3555.05
# [Episode 1229] | Loss: -0.0174
# Loss: -0.0102, Reward mean: -2654.41, Std: 2719.96
# [Episode 1230] | Loss: -0.0102
# Loss: 0.0019, Reward mean: -2202.86, Std: 1999.59
# [Episode 1231] | Loss: 0.0019
# Loss: -0.0060, Reward mean: -3490.91, Std: 2358.09
# [Episode 1232] | Loss: -0.0060
# Loss: -0.0039, Reward mean: -1279.63, Std: 2310.02
# [Episode 1233] | Loss: -0.0039
# Loss: 0.0037, Reward mean: -1157.73, Std: 2216.25
# [Episode 1234] | Loss: 0.0037
# Loss: -0.0009, Reward mean: -749.12, Std: 1936.79
# [Episode 1235] | Loss: -0.0009
# Loss: -0.0031, Reward mean: 6115.35, Std: 2229.33
# [Episode 1236] | Loss: -0.0031
# Loss: -0.0042, Reward mean: 3802.18, Std: 6496.02
# [Episode 1237] | Loss: -0.0042
# Loss: -0.0000, Reward mean: 0.00, Std: 0.00
# [Episode 
# Loss: -0.0333, Reward mean: -889.91, Std: 2014.15
# [Episode 3686] | Loss: -0.0333
# Loss: -0.0262, Reward mean: -2093.50, Std: 3440.60
# [Episode 3687] | Loss: -0.0262
# Loss: -0.0000, Reward mean: 45.00, Std: 0.00
# [Episode 3688] | Loss: -0.0000
# Loss: 0.0020, Reward mean: -1434.34, Std: 2769.87
# [Episode 3689] | Loss: 0.0020
# Loss: 0.0397, Reward mean: 2654.63, Std: 5925.75
# [Episode 3690] | Loss: 0.0397
# Loss: 0.0389, Reward mean: 3944.84, Std: 6406.21
# [Episode 3691] | Loss: 0.0389
# Loss: 0.0133, Reward mean: 4253.04, Std: 7194.36
# [Episode 3692] | Loss: 0.0133
# Loss: -0.0306, Reward mean: -638.64, Std: 1828.21
# [Episode 3693] | Loss: -0.0306
# Loss: -0.0231, Reward mean: -1306.15, Std: 2176.89
# [Episode 3694] | Loss: -0.0231
# Loss: 0.0027, Reward mean: 2176.42, Std: 4251.24
# [Episode 3695] | Loss: 0.0027
# Loss: 0.0096, Reward mean: -1399.35, Std: 2695.10
# [Episode 3696] | Loss: 0.0096
# Loss: 0.0241, Reward mean: 2852.07, Std: 6070.12
# [Episode 3697] | Loss: 0.0241
# Loss: -0.0426, Reward mean: -1920.32, Std: 2578.75
# [Episode 3698] | Loss: -0.0426
# Loss: 0.0030, Reward mean: -1491.46, Std: 2539.57
# [Episode 3699] | Loss: 0.0030
# Loss: -0.0147, Reward mean: -889.14, Std: 1445.26
# [Episode 3700] | Loss: -0.0147
# ✓ Model saved at ep 3700
# Loss: -0.0231, Reward mean: -1488.86, Std: 2464.52
# [Episode 3701] | Loss: -0.0231
# Loss: -0.0098, Reward mean: 8284.03, Std: 8293.01
# [Episode 3702] | Loss: -0.0098
# Loss: -0.0236, Reward mean: -4388.53, Std: 3487.81
# [Episode 3703] | Loss: -0.0236
# Loss: 0.0328, Reward mean: -1135.18, Std: 2819.30
# [Episode 3704] | Loss: 0.0328
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-d3b0abca9127> in <cell line: 0>()
#      21         for pid in range(4)
#      22     ]
# ---> 23     logs = simulate_hanchan(bots, gamma=1.0)
#      24     loss = train_pg(models["action"], optimizers["action"], logs)
#      25     # while not env.is_over():
#
# <ipython-input-74-6ab8322ec8df> in simulate_hanchan(bots, gamma, placement_bonus)
#      52
#      53                     action = bots[pid].act(obs, valid, reward)
# ---> 54                     env.step(pid, action)
#      55
#      56                     if pid == 0:
#
# /usr/local/lib/python3.11/dist-packages/pymahjong/env_pymahjong.py in step(self, player_id, action)
#     303             self.may_riichi_tile_id = None
#     304
# --> 305         self._proceed()
#     306
#     307     def _get_obs_from_table(self, player_id):
#
# /usr/local/lib/python3.11/dist-packages/pymahjong/env_pymahjong.py in _proceed(self)
#      86                 break
#      87             else:
# ---> 88                 self.t.make_selection(0)
#      89
#      90     def _get_num_aval_actions(self):
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn.functional as F
import numpy as np
import random
from pymahjong import MahjongEnv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Load trained model ---
class MahjongCNNBase(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(93, 64, kernel_size=(3, 1), padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=(3, 1), padding=0),
            nn.ReLU(),
            nn.Flatten()
        )
        self.output_dim = self._get_output_dim()

    def _get_output_dim(self):
        dummy = torch.zeros((1, 93, 34, 1))
        return self.conv(dummy).shape[1]

    def forward(self, x):
        return self.conv(x)

class DiscreteHead(nn.Module):
    def __init__(self, base, output_size):
        super().__init__()
        self.base = base
        self.head = nn.Sequential(
            nn.Linear(base.output_dim, 256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )

    def forward(self, x):
        return self.head(self.base(x))

def encode_game_state(obs):
    obs = np.array(obs, dtype=np.float32)
    return torch.tensor(obs).unsqueeze(0).unsqueeze(-1).to(device)

# --- Define agents ---
class RandomBot:
    def __init__(self, pid):
        self.pid = pid

    def act(self, obs, valid_actions):
        return random.choice(valid_actions)

TERMINAL_HONOR_INDICES = set([
    0, 8, 9, 17, 18, 26, 27, 28, 29, 30, 31, 32, 33
])

WIN_INDICES = set([42,43])

def terminal_honor_win_action(valid_actions):
    # Filter for discard actions only (0–33)

    win_actions = [a for a in valid_actions if a in WIN_INDICES]
    if win_actions:
        return np.random.choice(win_actions)
    terminal_honor_discards = [a for a in valid_actions if a in TERMINAL_HONOR_INDICES]

    if terminal_honor_discards:
        return np.random.choice(terminal_honor_discards)
    else:
        return np.random.choice(valid_actions)

class TerminalBot:
    def __init__(self, pid):
        self.pid = pid

    def act(self, obs, valid_actions):
        return terminal_honor_win_action(valid_actions)

class TrainedBot:
    def __init__(self, pid, model):
        self.pid = pid
        self.model = model

    def act(self, obs, valid_actions):
        state = encode_game_state(obs)  # shape: (1, 93, 34, 1)
        logits = self.model(state).squeeze(0)
        valid_logits = logits[valid_actions]
        probs = F.softmax(valid_logits, dim=0).detach().cpu().numpy()
        index = np.random.choice(len(valid_actions), p=probs)
        return valid_actions[index]

# --- Load model ---
base = MahjongCNNBase().to(device)
model = DiscreteHead(base, 136).to(device)
model.load_state_dict(torch.load("./checkpoints/ep_1200/action.pt", map_location=torch.device('cpu')))
model.eval()

# --- Evaluation loop ---
NUM_GAMES = 1
total_payoff = 0
env = MahjongEnv()

for game in range(NUM_GAMES):
    env.reset()
    bots = [
        TrainingBot(0, model),
        TerminalBot(1),
        TerminalBot(2),
        TerminalBot(3)
    ]
    simulate_hanchan(bots=bots)
    while not env.is_over():
        pid = env.get_curr_player_id()
        obs = env.get_obs(pid)
        valid = env.get_valid_actions()
        action = bots[pid].act(obs, valid)
        env.step(pid, action)

    payoffs = env.get_payoffs()
    total_payoff += payoffs[0]
    print(f"Game {game + 1}: payoff = {payoffs[0]}")

avg = total_payoff / NUM_GAMES
print(f"\nAverage payoff over {NUM_GAMES} games: {avg:.2f}")
print(f"\n total is {total_payoff}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-95f94d69f045> in <cell line: 0>()
#     105     env.reset()
#     106     bots = [
# --> 107         TrainingBot(0, model),
#     108         TerminalBot(1),
#     109         TerminalBot(2),
#
# TypeError: TrainingBot.__init__() missing 1 required positional argument: 'logs'

# %%
import torch
import torch.nn.functional as F
import numpy as np
import random
from pymahjong import MahjongEnv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # --- Load trained model ---
# class MahjongCNNBase(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv = nn.Sequential(
#             nn.Conv2d(93, 64, kernel_size=(3, 1), padding=0),
#             nn.ReLU(),
#             nn.Conv2d(64, 64, kernel_size=(3, 1), padding=0),
#             nn.ReLU(),
#             nn.Flatten()
#         )
#         self.output_dim = self._get_output_dim()

#     def _get_output_dim(self):
#         dummy = torch.zeros((1, 93, 34, 1))
#         return self.conv(dummy).shape[1]

#     def forward(self, x):
#         return self.conv(x)

# class DiscreteHead(nn.Module):
#     def __init__(self, base, output_size):
#         super().__init__()
#         self.base = base
#         self.head = nn.Sequential(
#             nn.Linear(base.output_dim, 256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )

#     def forward(self, x):
#         return self.head(self.base(x))

# def encode_game_state(obs):
#     obs = np.array(obs, dtype=np.float32)
#     return torch.tensor(obs).unsqueeze(0).unsqueeze(-1).to(device)

# # --- Define agents ---
# class RandomBot:
#     def __init__(self, pid):
#         self.pid = pid

#     def act(self, obs, valid_actions):
#         return random.choice(valid_actions)

class TrainedBot:
    def __init__(self, pid, model):
        self.pid = pid
        self.model = model

    def act(self, obs, valid_actions):
        state = encode_game_state(obs)  # shape: (1, 93, 34, 1)
        logits = self.model(state).squeeze(0)
        valid_logits = logits[valid_actions]
        probs = F.softmax(valid_logits, dim=0).detach().cpu().numpy()
        index = np.random.choice(len(valid_actions), p=probs)
        return valid_actions[index]

# --- Load model ---
base = MahjongCNNBase().to(device)
model = DiscreteHead(base, 136).to(device)
model.load_state_dict(torch.load("./checkpoints/ep_3700/action.pt", map_location=torch.device("cpu")))
model.eval()

# --- Evaluation loop ---
NUM_GAMES = 1000
total_payoff = 0
env = MahjongEnv()

for game in range(NUM_GAMES):
    env.reset()
    bots = [
        TrainedBot(0, model),
        TerminalBot(1),
        TerminalBot(2),
        TerminalBot(3)
    ]
    #play a hanchan

    while not env.is_over():
        pid = env.get_curr_player_id()
        obs = env.get_obs(pid)
        valid = env.get_valid_actions()
        action = bots[pid].act(obs, valid)



        # env.render()  # ← this prints the table state
        env.step(pid, action)

    payoffs = env.get_payoffs()
    total_payoff += payoffs[0]
    print(f"Game {game + 1}: payoff = {payoffs[0]}")

avg = total_payoff / NUM_GAMES
print(f"\nAverage payoff over {NUM_GAMES} games: {avg:.2f}")
# Out:
# Game 1: payoff = 0.0
# Game 2: payoff = 0.0
# Game 3: payoff = 0.0
# Game 4: payoff = -1500.0
# Game 5: payoff = 0.0
# Game 6: payoff = 0.0
# Game 7: payoff = 0.0
# Game 8: payoff = -1000.0
# Game 9: payoff = 0.0
# Game 10: payoff = 0.0
# Game 11: payoff = 0.0
# Game 12: payoff = -3900.0
# Game 13: payoff = 0.0
# Game 14: payoff = -1000.0
# Game 15: payoff = 0.0
# Game 16: payoff = 0.0
# Game 17: payoff = 0.0
# Game 18: payoff = -1000.0
# Game 19: payoff = -1000.0
# Game 20: payoff = 0.0
# Game 21: payoff = -1500.0
# Game 22: payoff = -1000.0
# Game 23: payoff = 0.0
# Game 24: payoff = 0.0
# Game 25: payoff = 0.0
# Game 26: payoff = 0.0
# Game 27: payoff = 0.0
# Game 28: payoff = -1000.0
# Game 29: payoff = 0.0
# Game 30: payoff = 0.0
# Game 31: payoff = -1000.0
# Game 32: payoff = -1500.0
# Game 33: payoff = -1500.0
# Game 34: payoff = -1500.0
# Game 35: payoff = -1500.0
# Game 36: payoff = -1000.0
# Game 37: payoff = 0.0
# Game 38: payoff = -1000.0
# Game 39: payoff = 0.0
# Game 40: payoff = -1000.0
# Game 41: payoff = -1500.0
# Game 42: payoff = -1000.0
# Game 43: payoff = -2000.0
# Game 44: payoff = -1000.0
# Game 45: payoff = -1000.0
# Game 46: payoff = -1000.0
# Game 47: payoff = -1000.0
# Game 48: payoff = -1000.0
# Game 49: payoff = -1000.0
# Game 50: payoff = -1000.0
# Game 51: payoff = 0.0
# Game 52: payoff = 0.0
# Game 53: payoff = 0.0
# Game 54: payoff = -1000.0
# Game 55: payoff = -1000.0
# Game 56: payoff = 0.0
# Game 57: payoff = 0.0
# Game 58: payoff = 0.0
# Game 59: payoff = -1000.0
# Game 60: payoff = 0.0
# Game 61: payoff = -1000.0
# Game 62: payoff = -1500.0
# Game 63: payoff = 0.0
# Game 64: payoff = 1500.0
# Game 65: payoff = -3000.0
# Game 66: payoff = 0.0
# Game 67: payoff = 0.0
# Game 68: payoff = 0.0
# Game 69: payoff = -1000.0
# Game 70: payoff = 0.0
# Game 71: payoff = -1000.0
# Game 72: payoff = 0.0
# Game 73: payoff = 0.0
# Game 74: payoff = -1000.0
# Game 75: payoff = -1000.0
# Game 76: payoff = 0.0
# Game 77: payoff = -1000.0
# Game 78: payoff = 0.0
# Game 79: payoff = 0.0
# Game 80: payoff = -1000.0
# Game 81: payoff = -1000.0
# Game 82: payoff = 0.0
# Game 83: payoff = -1000.0
# Game 84: payoff = 0.0
# Game 85: payoff = 0.0
# Game 86: payoff = -1000.0
# Game 87: payoff = 0.0
# Game 88: payoff = -1000.0
# Game 89: payoff = 0.0
# Game 90: payoff = -1000.0
# Game 91: payoff = 0.0
# Game 92: payoff = 0.0
# Game 93: payoff = -1000.0
# Game 94: payoff = -1000.0
# Game 95: payoff = 0.0
# Game 96: payoff = 0.0
# Game 97: payoff = -1000.0
# Game 98: payoff = -1500.0
# Game 99: payoff = 0.0
# Game 100: payoff = -1000.0
# Game 101: payoff = 0.0
# Game 102: payoff = -1500.0
# Game 103: payoff = 0.0
# Game 104: payoff = 0.0
# Game 105: payoff = 0.0
# Game 106: payoff = 0.0
# Game 107: payoff = -1000.0
# Game 108: payoff = 0.0
# Game 109: payoff = -500.0
# Game 110: payoff = -1000.0
# Game 111: payoff = -3000.0
# Game 112: payoff = 0.0
# Game 113: payoff = -1000.0
# Game 114: payoff = 0.0
# Game 115: payoff = 0.0
# Game 116: payoff = 0.0
# Game 117: payoff = 0.0
# Game 118: payoff = 0.0
# Game 119: payoff = -1000.0
# Game 120: payoff = -1000.0
# Game 121: payoff = -1000.0
# Game 122: payoff = -1000.0
# Game 123: payoff = -500.0
# Game 124: payoff = -1000.0
# Game 125: payoff = 0.0
# Game 126: payoff = 0.0
# Game 127: payoff = -1000.0
# Game 128: payoff = -1000.0
# Game 129: payoff = 1500.0
# Game 130: payoff = 0.0
# Game 131: payoff = -1000.0
# Game 132: payoff = 0.0
# Game 133: payoff = -500.0
# Game 134: payoff = -1000.0
# Game 135: payoff = -1000.0
# Game 136: payoff = -1000.0
# Game 137: payoff = 0.0
# Game 138: payoff = -1000.0
# Game 139: payoff = -1000.0
# Game 140: payoff = 0.0
# Game 141: payoff = 0.0
# Game 142: payoff = -1000.0
# Game 143: payoff = 0.0
# Game 144: payoff = 0.0
# Game 145: payoff = 0.0
# Game 146: payoff = -1500.0
# Game 147: payoff = 0.0
# Game 148: payoff = 0.0
# Game 149: payoff = -1000.0
# Game 150: payoff = 0.0
# Game 151: payoff = -1000.0
# Game 152: payoff = 0.0
# Game 153: payoff = -1000.0
# Game 154: payoff = 0.0
# Game 155: payoff = 0.0
# Game 156: payoff = 0.0
# Game 157: payoff = 0.0
# Game 158: payoff = 0.0
# Game 159: payoff = 0.0
# Game 160: payoff = 0.0
# Game 161: payoff = 0.0
# Game 162: payoff = 0.0
# Game 163: payoff = 0.0
# Game 164: payoff = 0.0
# Game 165: payoff = 0.0
# Game 166: payoff = 0.0
# Game 167: payoff = 0.0
# Game 168: payoff = -1000.0
# Game 169: payoff = -1500.0
# Game 170: payoff = 0.0
# Game 171: payoff = -1000.0
# Game 172: payoff = 0.0
# Game 173: payoff = 0.0
# Game 174: payoff = 0.0
# Game 175: payoff = -1000.0
# Game 176: payoff = 0.0
# Game 177: payoff = 0.0
# Game 178: payoff = 0.0
# Game 179: payoff = -1500.0
# Game 180: payoff = 0.0
# Game 181: payoff = -1000.0
# Game 182: payoff = -1000.0
# Game 183: payoff = 0.0
# Game 184: payoff = -3900.0
# Game 185: payoff = 0.0
# Game 186: payoff = -1000.0
# Game 187: payoff = 0.0
# Game 188: payoff = -1500.0
# Game 189: payoff = 0.0
# Game 190: payoff = -1000.0
# Game 191: payoff = 0.0
# Game 192: payoff = 0.0
# Game 193: payoff = -1500.0
# Game 194: payoff = 0.0
# Game 195: payoff = -1000.0
# Game 196: payoff = 0.0
# Game 197: payoff = 0.0
# Game 198: payoff = -1000.0
# Game 199: payoff = -1500.0
# Game 200: payoff = -1000.0
# Game 201: payoff = 0.0
# Game 202: payoff = -1500.0
# Game 203: payoff = -500.0
# Game 204: payoff = 0.0
# Game 205: payoff = -1000.0
# Game 206: payoff = -1000.0
# Game 207: payoff = -1000.0
# Game 208: payoff = 0.0
# Game 209: payoff = 0.0
# Game 210: payoff = 0.0
# Game 211: payoff = -1500.0
# Game 212: payoff = 0.0
# Game 213: payoff = -1000.0
# Game 214: payoff = -1000.0
# Game 215: payoff = 0.0
# Game 216: payoff = 0.0
# Game 217: payoff = -1000.0
# Game 218: payoff = 0.0
# Game 219: payoff = 0.0
# Game 220: payoff = -1000.0
# Game 221: payoff = -1500.0
# Game 222: payoff = 0.0
# Game 223: payoff = 0.0
# Game 224: payoff = 0.0
# Game 225: payoff = -1500.0
# Game 226: payoff = 0.0
# Game 227: payoff = -1000.0
# Game 228: payoff = -1000.0
# Game 229: payoff = 0.0
# Game 230: payoff = 0.0
# Game 231: payoff = -300.0
# Game 232: payoff = -1000.0
# Game 233: payoff = 0.0
# Game 234: payoff = 0.0
# Game 235: payoff = 0.0
# Game 236: payoff = 0.0
# Game 237: payoff = 0.0
# Game 238: payoff = -1000.0
# Game 239: payoff = -1500.0
# Game 240: payoff = 0.0
# Game 241: payoff = -1000.0
# Game 242: payoff = 0.0
# Game 243: payoff = 0.0
# Game 244: payoff = -1500.0
# Game 245: payoff = 0.0
# Game 246: payoff = -1000.0
# Game 247: payoff = 0.0
# Game 248: payoff = -1000.0
# Game 249: payoff = -1000.0
# Game 250: payoff = 0.0
# Game 251: payoff = -1000.0
# Game 252: payoff = -1500.0
# Game 253: payoff = 0.0
# Game 254: payoff = 0.0
# Game 255: payoff = 0.0
# Game 256: payoff = 0.0
# Game 257: payoff = 0.0
# Game 258: payoff = 0.0
# Game 259: payoff = 0.0
# Game 260: payoff = -1500.0
# Game 261: payoff = 0.0
# Game 262: payoff = -1000.0
# Game 263: payoff = 0.0
# Game 264: payoff = -1000.0
# Game 265: payoff = -1000.0
# Game 266: payoff = 1500.0
# Game 267: payoff = -1000.0
# Game 268: payoff = -1000.0
# Game 269: payoff = 0.0
# Game 270: payoff = 0.0
# Game 271: payoff = 0.0
# Game 272: payoff = 0.0
# Game 273: payoff = -4000.0
# Game 274: payoff = -1500.0
# Game 275: payoff = -1000.0
# Game 276: payoff = 0.0
# Game 277: payoff = 0.0
# Game 278: payoff = 0.0
# Game 279: payoff = 0.0
# Game 280: payoff = -1500.0
# Game 281: payoff = -1500.0
# Game 282: payoff = 0.0
# Game 283: payoff = -1500.0
# Game 284: payoff = 0.0
# Game 285: payoff = -1000.0
# Game 286: payoff = -1500.0
# Game 287: payoff = 0.0
# Game 288: payoff = -1000.0
# Game 289: payoff = 0.0
# Game 290: payoff = 0.0
# Game 291: payoff = -1000.0
# Game 292: payoff = -1000.0
# Game 293: payoff = 3000.0
# Game 294: payoff = 0.0
# Game 295: payoff = 0.0
# Game 296: payoff = 0.0
# Game 297: payoff = 0.0
# Game 298: payoff = -1500.0
# Game 299: payoff = 0.0
# Game 300: payoff = -1000.0
# Game 301: payoff = -1500.0
# Game 302: payoff = -1000.0
# Game 303: payoff = -3000.0
# Game 304: payoff = 0.0
# Game 305: payoff = -1000.0
# Game 306: payoff = -1500.0
# Game 307: payoff = -1000.0
# Game 308: payoff = -3000.0
# Game 309: payoff = 0.0
# Game 310: payoff = -1500.0
# Game 311: payoff = 0.0
# Game 312: payoff = 0.0
# Game 313: payoff = -1000.0
# Game 314: payoff = 0.0
# Game 315: payoff = -1500.0
# Game 316: payoff = -1500.0
# Game 317: payoff = -1000.0
# Game 318: payoff = 0.0
# Game 319: payoff = -1500.0
# Game 320: payoff = -1000.0
# Game 321: payoff = -500.0
# Game 322: payoff = 1000.0
# Game 323: payoff = -1000.0
# Game 324: payoff = -1500.0
# Game 325: payoff = 0.0
# Game 326: payoff = -1500.0
# Game 327: payoff = 0.0
# Game 328: payoff = 0.0
# Game 329: payoff = 0.0
# Game 330: payoff = 0.0
# Game 331: payoff = 0.0
# Game 332: payoff = -1000.0
# Game 333: payoff = -500.0
# Game 334: payoff = -1000.0
# Game 335: payoff = -1000.0
# Game 336: payoff = -1000.0
# Game 337: payoff = -1000.0
# Game 338: payoff = -1300.0
# Game 339: payoff = 0.0
# Game 340: payoff = -1000.0
# Game 341: payoff = -1000.0
# Game 342: payoff = -1000.0
# Game 343: payoff = 3000.0
# Game 344: payoff = -1000.0
# Game 345: payoff = -1000.0
# Game 346: payoff = -1000.0
# Game 347: payoff = -1000.0
# Game 348: payoff = 2000.0
# Game 349: payoff = -1500.0
# Game 350: payoff = -1000.0
# Game 351: payoff = -1000.0
# Game 352: payoff = -1000.0
# Game 353: payoff = 0.0
# Game 354: payoff = 0.0
# Game 355: payoff = -1000.0
# Game 356: payoff = -1000.0
# Game 357: payoff = 0.0
# Game 358: payoff = 0.0
# Game 359: payoff = -1500.0
# Game 360: payoff = 0.0
# Game 361: payoff = -1000.0
# Game 362: payoff = -1500.0
# Game 363: payoff = 0.0
# Game 364: payoff = 0.0
# Game 365: payoff = -1000.0
# Game 366: payoff = -1000.0
# Game 367: payoff = 0.0
# Game 368: payoff = 0.0
# Game 369: payoff = -1500.0
# Game 370: payoff = 0.0
# Game 371: payoff = -1000.0
# Game 372: payoff = -1000.0
# Game 373: payoff = -1000.0
# Game 374: payoff = 0.0
# Game 375: payoff = -3900.0
# Game 376: payoff = 0.0
# Game 377: payoff = -1300.0
# Game 378: payoff = 0.0
# Game 379: payoff = -1000.0
# Game 380: payoff = -1000.0
# Game 381: payoff = 0.0
# Game 382: payoff = -1000.0
# Game 383: payoff = -1000.0
# Game 384: payoff = 0.0
# Game 385: payoff = -1000.0
# Game 386: payoff = -1000.0
# Game 387: payoff = 0.0
# Game 388: payoff = -1000.0
# Game 389: payoff = -1000.0
# Game 390: payoff = -1500.0
# Game 391: payoff = 0.0
# Game 392: payoff = 0.0
# Game 393: payoff = 0.0
# Game 394: payoff = 0.0
# Game 395: payoff = -1000.0
# Game 396: payoff = 0.0
# Game 397: payoff = 0.0
# Game 398: payoff = -1000.0
# Game 399: payoff = -1000.0
# Game 400: payoff = 0.0
# Game 401: payoff = -1500.0
# Game 402: payoff = -1500.0
# Game 403: payoff = -1000.0
# Game 404: payoff = -1000.0
# Game 405: payoff = -1500.0
# Game 406: payoff = 0.0
# Game 407: payoff = 0.0
# Game 408: payoff = 0.0
# Game 409: payoff = -1000.0
# Game 410: payoff = -1000.0
# Game 411: payoff = 0.0
# Game 412: payoff = 0.0
# Game 413: payoff = -1000.0
# Game 414: payoff = -1000.0
# Game 415: payoff = 0.0
# Game 416: payoff = -1000.0
# Game 417: payoff = -1000.0
# Game 418: payoff = -1500.0
# Game 419: payoff = -1000.0
# Game 420: payoff = -1000.0
# Game 421: payoff = 0.0
# Game 422: payoff = -1000.0
# Game 423: payoff = 0.0
# Game 424: payoff = 0.0
# Game 425: payoff = -1000.0
# Game 426: payoff = 0.0
# Game 427: payoff = -1000.0
# Game 428: payoff = -1500.0
# Game 429: payoff = -1000.0
# Game 430: payoff = -1000.0
# Game 431: payoff = 0.0
# Game 432: payoff = 0.0
# Game 433: payoff = 0.0
# Game 434: payoff = 0.0
# Game 435: payoff = -1000.0
# Game 436: payoff = -1000.0
# Game 437: payoff = 0.0
# Game 438: payoff = -1000.0
# Game 439: payoff = -1000.0
# Game 440: payoff = -1000.0
# Game 441: payoff = -1000.0
# Game 442: payoff = -1000.0
# Game 443: payoff = -1000.0
# Game 444: payoff = -1000.0
# Game 445: payoff = -1000.0
# Game 446: payoff = -1000.0
# Game 447: payoff = 0.0
# Game 448: payoff = 0.0
# Game 449: payoff = 0.0
# Game 450: payoff = -1000.0
# Game 451: payoff = 3000.0
# Game 452: payoff = 0.0
# Game 453: payoff = -1000.0
# Game 454: payoff = -1500.0
# Game 455: payoff = -1000.0
# Game 456: payoff = -1000.0
# Game 457: payoff = 0.0
# Game 458: payoff = 0.0
# Game 459: payoff = 0.0
# Game 460: payoff = 0.0
# Game 461: payoff = 0.0
# Game 462: payoff = -1000.0
# Game 463: payoff = -1000.0
# Game 464: payoff = 0.0
# Game 465: payoff = -1000.0
# Game 466: payoff = 0.0
# Game 467: payoff = -1000.0
# Game 468: payoff = -1000.0
# Game 469: payoff = -1000.0
# Game 470: payoff = -1000.0
# Game 471: payoff = -300.0
# Game 472: payoff = -1000.0
# Game 473: payoff = -1000.0
# Game 474: payoff = -1500.0
# Game 475: payoff = 0.0
# Game 476: payoff = -7700.0
# Game 477: payoff = -1000.0
# Game 478: payoff = -2900.0
# Game 479: payoff = -1500.0
# Game 480: payoff = -1000.0
# Game 481: payoff = -1000.0
# Game 482: payoff = -1500.0
# Game 483: payoff = -1000.0
# Game 484: payoff = -1000.0
# Game 485: payoff = 0.0
# Game 486: payoff = -1500.0
# Game 487: payoff = -1500.0
# Game 488: payoff = 0.0
# Game 489: payoff = -1000.0
# Game 490: payoff = -1000.0
# Game 491: payoff = 0.0
# Game 492: payoff = 0.0
# Game 493: payoff = 0.0
# Game 494: payoff = -1000.0
# Game 495: payoff = 0.0
# Game 496: payoff = 0.0
# Game 497: payoff = 0.0
# Game 498: payoff = 0.0
# Game 499: payoff = 0.0
# Game 500: payoff = 0.0
# Game 501: payoff = 0.0
# Game 502: payoff = -1500.0
# Game 503: payoff = 0.0
# Game 504: payoff = 0.0
# Game 505: payoff = -1000.0
# Game 506: payoff = 0.0
# Game 507: payoff = -1000.0
# Game 508: payoff = 0.0
# Game 509: payoff = 0.0
# Game 510: payoff = -1000.0
# Game 511: payoff = -1500.0
# Game 512: payoff = -1000.0
# Game 513: payoff = 0.0
# Game 514: payoff = -1500.0
# Game 515: payoff = 0.0
# Game 516: payoff = 0.0
# Game 517: payoff = 0.0
# Game 518: payoff = -1000.0
# Game 519: payoff = -1000.0
# Game 520: payoff = -1000.0
# Game 521: payoff = 0.0
# Game 522: payoff = 0.0
# Game 523: payoff = 0.0
# Game 524: payoff = 0.0
# Game 525: payoff = 0.0
# Game 526: payoff = -1000.0
# Game 527: payoff = -3000.0
# Game 528: payoff = 0.0
# Game 529: payoff = -1000.0
# Game 530: payoff = 0.0
# Game 531: payoff = 0.0
# Game 532: payoff = 0.0
# Game 533: payoff = 0.0
# Game 534: payoff = 0.0
# Game 535: payoff = 0.0
# Game 536: payoff = -1000.0
# Game 537: payoff = 0.0
# Game 538: payoff = 0.0
# Game 539: payoff = -1000.0
# Game 540: payoff = 0.0
# Game 541: payoff = 0.0
# Game 542: payoff = 0.0
# Game 543: payoff = 1000.0
# Game 544: payoff = -1500.0
# Game 545: payoff = 0.0
# Game 546: payoff = -1000.0
# Game 547: payoff = -1000.0
# Game 548: payoff = 0.0
# Game 549: payoff = 0.0
# Game 550: payoff = -1500.0
# Game 551: payoff = -1500.0
# Game 552: payoff = 0.0
# Game 553: payoff = -1000.0
# Game 554: payoff = 0.0
# Game 555: payoff = -1000.0
# Game 556: payoff = -1000.0
# Game 557: payoff = -1000.0
# Game 558: payoff = 0.0
# Game 559: payoff = -1500.0
# Game 560: payoff = -1000.0
# Game 561: payoff = -1000.0
# Game 562: payoff = 0.0
# Game 563: payoff = -1000.0
# Game 564: payoff = 0.0
# Game 565: payoff = -2000.0
# Game 566: payoff = 0.0
# Game 567: payoff = -1000.0
# Game 568: payoff = -1000.0
# Game 569: payoff = 0.0
# Game 570: payoff = -1000.0
# Game 571: payoff = 0.0
# Game 572: payoff = -1000.0
# Game 573: payoff = -1000.0
# Game 574: payoff = -1000.0
# Game 575: payoff = -1000.0
# Game 576: payoff = 1500.0
# Game 577: payoff = -4000.0
# Game 578: payoff = 0.0
# Game 579: payoff = 0.0
# Game 580: payoff = 0.0
# Game 581: payoff = -1000.0
# Game 582: payoff = 0.0
# Game 583: payoff = 0.0
# Game 584: payoff = -1500.0
# Game 585: payoff = 0.0
# Game 586: payoff = 0.0
# Game 587: payoff = -1000.0
# Game 588: payoff = 0.0
# Game 589: payoff = 0.0
# Game 590: payoff = -300.0
# Game 591: payoff = -1500.0
# Game 592: payoff = -1000.0
# Game 593: payoff = -1500.0
# Game 594: payoff = 0.0
# Game 595: payoff = -1000.0
# Game 596: payoff = 0.0
# Game 597: payoff = 0.0
# Game 598: payoff = -1000.0
# Game 599: payoff = 0.0
# Game 600: payoff = 0.0
# Game 601: payoff = -1000.0
# Game 602: payoff = 0.0
# Game 603: payoff = 0.0
# Game 604: payoff = -1000.0
# Game 605: payoff = -1000.0
# Game 606: payoff = 0.0
# Game 607: payoff = -1000.0
# Game 608: payoff = -1500.0
# Game 609: payoff = 0.0
# Game 610: payoff = -1000.0
# Game 611: payoff = -1000.0
# Game 612: payoff = 0.0
# Game 613: payoff = 0.0
# Game 614: payoff = -1000.0
# Game 615: payoff = -1000.0
# Game 616: payoff = 0.0
# Game 617: payoff = 0.0
# Game 618: payoff = 0.0
# Game 619: payoff = -1000.0
# Game 620: payoff = -1000.0
# Game 621: payoff = -1000.0
# Game 622: payoff = -300.0
# Game 623: payoff = 0.0
# Game 624: payoff = -1000.0
# Game 625: payoff = 0.0
# Game 626: payoff = 0.0
# Game 627: payoff = 0.0
# Game 628: payoff = -1500.0
# Game 629: payoff = 0.0
# Game 630: payoff = -1000.0
# Game 631: payoff = 0.0
# Game 632: payoff = 0.0
# Game 633: payoff = -1000.0
# Game 634: payoff = -1500.0
# Game 635: payoff = 0.0
# Game 636: payoff = 0.0
# Game 637: payoff = 0.0
# Game 638: payoff = -1000.0
# Game 639: payoff = -1500.0
# Game 640: payoff = 0.0
# Game 641: payoff = 0.0
# Game 642: payoff = 0.0
# Game 643: payoff = -1000.0
# Game 644: payoff = -3000.0
# Game 645: payoff = 0.0
# Game 646: payoff = 0.0
# Game 647: payoff = 0.0
# Game 648: payoff = -1500.0
# Game 649: payoff = -1000.0
# Game 650: payoff = 0.0
# Game 651: payoff = -500.0
# Game 652: payoff = -1000.0
# Game 653: payoff = 0.0
# Game 654: payoff = 0.0
# Game 655: payoff = 0.0
# Game 656: payoff = -2600.0
# Game 657: payoff = -1000.0
# Game 658: payoff = 0.0
# Game 659: payoff = 0.0
# Game 660: payoff = 0.0
# Game 661: payoff = -1000.0
# Game 662: payoff = 0.0
# Game 663: payoff = 0.0
# Game 664: payoff = 0.0
# Game 665: payoff = 0.0
# Game 666: payoff = 0.0
# Game 667: payoff = 0.0
# Game 668: payoff = -1000.0
# Game 669: payoff = -1500.0
# Game 670: payoff = -1000.0
# Game 671: payoff = 0.0
# Game 672: payoff = -1000.0
# Game 673: payoff = 0.0
# Game 674: payoff = 0.0
# Game 675: payoff = -1000.0
# Game 676: payoff = 0.0
# Game 677: payoff = 0.0
# Game 678: payoff = 0.0
# Game 679: payoff = 0.0
# Game 680: payoff = -3000.0
# Game 681: payoff = -1000.0
# Game 682: payoff = 0.0
# Game 683: payoff = 0.0
# Game 684: payoff = -1000.0
# Game 685: payoff = 0.0
# Game 686: payoff = 0.0
# Game 687: payoff = -1000.0
# Game 688: payoff = -1000.0
# Game 689: payoff = 0.0
# Game 690: payoff = -1000.0
# Game 691: payoff = 0.0
# Game 692: payoff = -1300.0
# Game 693: payoff = 0.0
# Game 694: payoff = -1000.0
# Game 695: payoff = 0.0
# Game 696: payoff = 0.0
# Game 697: payoff = 0.0
# Game 698: payoff = 0.0
# Game 699: payoff = -3000.0
# Game 700: payoff = 0.0
# Game 701: payoff = -1000.0
# Game 702: payoff = -1000.0
# Game 703: payoff = 0.0
# Game 704: payoff = -1500.0
# Game 705: payoff = -1000.0
# Game 706: payoff = -1000.0
# Game 707: payoff = 3000.0
# Game 708: payoff = -1000.0
# Game 709: payoff = -1000.0
# Game 710: payoff = -1000.0
# Game 711: payoff = -1000.0
# Game 712: payoff = 0.0
# Game 713: payoff = 0.0
# Game 714: payoff = -1000.0
# Game 715: payoff = 0.0
# Game 716: payoff = -1000.0
# Game 717: payoff = -1500.0
# Game 718: payoff = 0.0
# Game 719: payoff = -1000.0
# Game 720: payoff = 0.0
# Game 721: payoff = 0.0
# Game 722: payoff = 0.0
# Game 723: payoff = -1000.0
# Game 724: payoff = -1000.0
# Game 725: payoff = -1500.0
# Game 726: payoff = 0.0
# Game 727: payoff = 0.0
# Game 728: payoff = -1000.0
# Game 729: payoff = 0.0
# Game 730: payoff = 0.0
# Game 731: payoff = -1000.0
# Game 732: payoff = -1000.0
# Game 733: payoff = -1000.0
# Game 734: payoff = -1500.0
# Game 735: payoff = -1000.0
# Game 736: payoff = 0.0
# Game 737: payoff = -1000.0
# Game 738: payoff = -1000.0
# Game 739: payoff = 0.0
# Game 740: payoff = -1000.0
# Game 741: payoff = -1000.0
# Game 742: payoff = 0.0
# Game 743: payoff = -1000.0
# Game 744: payoff = 0.0
# Game 745: payoff = -1500.0
# Game 746: payoff = 0.0
# Game 747: payoff = 0.0
# Game 748: payoff = 0.0
# Game 749: payoff = -1500.0
# Game 750: payoff = -1000.0
# Game 751: payoff = 3000.0
# Game 752: payoff = -1000.0
# Game 753: payoff = 0.0
# Game 754: payoff = 0.0
# Game 755: payoff = -1500.0
# Game 756: payoff = 0.0
# Game 757: payoff = -1500.0
# Game 758: payoff = 0.0
# Game 759: payoff = -1000.0
# Game 760: payoff = 0.0
# Game 761: payoff = -1000.0
# Game 762: payoff = 0.0
# Game 763: payoff = 0.0
# Game 764: payoff = -1000.0
# Game 765: payoff = -1000.0
# Game 766: payoff = 0.0
# Game 767: payoff = -3000.0
# Game 768: payoff = 1300.0
# Game 769: payoff = -1000.0
# Game 770: payoff = 0.0
# Game 771: payoff = 0.0
# Game 772: payoff = 0.0
# Game 773: payoff = 0.0
# Game 774: payoff = -1000.0
# Game 775: payoff = 0.0
# Game 776: payoff = -1000.0
# Game 777: payoff = 0.0
# Game 778: payoff = 1500.0
# Game 779: payoff = 0.0
# Game 780: payoff = 0.0
# Game 781: payoff = -2000.0
# Game 782: payoff = -1500.0
# Game 783: payoff = -1500.0
# Game 784: payoff = -1500.0
# Game 785: payoff = 0.0
# Game 786: payoff = 0.0
# Game 787: payoff = 0.0
# Game 788: payoff = -1000.0
# Game 789: payoff = -1500.0
# Game 790: payoff = 0.0
# Game 791: payoff = 0.0
# Game 792: payoff = -1000.0
# Game 793: payoff = 0.0
# Game 794: payoff = -1000.0
# Game 795: payoff = -1000.0
# Game 796: payoff = -1000.0
# Game 797: payoff = -1000.0
# Game 798: payoff = -1000.0
# Game 799: payoff = 0.0
# Game 800: payoff = 0.0
# Game 801: payoff = 0.0
# Game 802: payoff = 0.0
# Game 803: payoff = -1000.0
# Game 804: payoff = -1000.0
# Game 805: payoff = -1000.0
# Game 806: payoff = -1000.0
# Game 807: payoff = 0.0
# Game 808: payoff = 0.0
# Game 809: payoff = 0.0
# Game 810: payoff = 1000.0
# Game 811: payoff = 0.0
# Game 812: payoff = -1500.0
# Game 813: payoff = -1000.0
# Game 814: payoff = -1000.0
# Game 815: payoff = -1500.0
# Game 816: payoff = 0.0
# Game 817: payoff = 0.0
# Game 818: payoff = 0.0
# Game 819: payoff = 0.0
# Game 820: payoff = -1000.0
# Game 821: payoff = 0.0
# Game 822: payoff = -1000.0
# Game 823: payoff = 0.0
# Game 824: payoff = 0.0
# Game 825: payoff = 0.0
# Game 826: payoff = -1000.0
# Game 827: payoff = -1000.0
# Game 828: payoff = 0.0
# Game 829: payoff = -1000.0
# Game 830: payoff = 0.0
# Game 831: payoff = -1000.0
# Game 832: payoff = -1000.0
# Game 833: payoff = 0.0
# Game 834: payoff = 0.0
# Game 835: payoff = -3000.0
# Game 836: payoff = -1000.0
# Game 837: payoff = 0.0
# Game 838: payoff = 0.0
# Game 839: payoff = 0.0
# Game 840: payoff = -1000.0
# Game 841: payoff = 0.0
# Game 842: payoff = 0.0
# Game 843: payoff = -1000.0
# Game 844: payoff = 0.0
# Game 845: payoff = 0.0
# Game 846: payoff = 0.0
# Game 847: payoff = -1000.0
# Game 848: payoff = 0.0
# Game 849: payoff = 0.0
# Game 850: payoff = 0.0
# Game 851: payoff = 0.0
# Game 852: payoff = -1500.0
# Game 853: payoff = 0.0
# Game 854: payoff = -1000.0
# Game 855: payoff = 0.0
# Game 856: payoff = 0.0
# Game 857: payoff = -1000.0
# Game 858: payoff = 0.0
# Game 859: payoff = 0.0
# Game 860: payoff = -1000.0
# Game 861: payoff = 0.0
# Game 862: payoff = -1000.0
# Game 863: payoff = -1000.0
# Game 864: payoff = -1000.0
# Game 865: payoff = 0.0
# Game 866: payoff = -1000.0
# Game 867: payoff = 0.0
# Game 868: payoff = 0.0
# Game 869: payoff = -1000.0
# Game 870: payoff = 0.0
# Game 871: payoff = 0.0
# Game 872: payoff = 0.0
# Game 873: payoff = -1000.0
# Game 874: payoff = -1000.0
# Game 875: payoff = -1000.0
# Game 876: payoff = -1000.0
# Game 877: payoff = -1000.0
# Game 878: payoff = -1500.0
# Game 879: payoff = 0.0
# Game 880: payoff = -1500.0
# Game 881: payoff = -1000.0
# Game 882: payoff = 0.0
# Game 883: payoff = -300.0
# Game 884: payoff = 0.0
# Game 885: payoff = 0.0
# Game 886: payoff = -1000.0
# Game 887: payoff = 0.0
# Game 888: payoff = 0.0
# Game 889: payoff = 0.0
# Game 890: payoff = 0.0
# Game 891: payoff = -1000.0
# Game 892: payoff = 0.0
# Game 893: payoff = 0.0
# Game 894: payoff = 0.0
# Game 895: payoff = 0.0
# Game 896: payoff = -1000.0
# Game 897: payoff = -1000.0
# Game 898: payoff = 0.0
# Game 899: payoff = -1000.0
# Game 900: payoff = -1500.0
# Game 901: payoff = 0.0
# Game 902: payoff = 0.0
# Game 903: payoff = -1000.0
# Game 904: payoff = -1000.0
# Game 905: payoff = 0.0
# Game 906: payoff = 0.0
# Game 907: payoff = -1000.0
# Game 908: payoff = -1000.0
# Game 909: payoff = -1000.0
# Game 910: payoff = -1000.0
# Game 911: payoff = 0.0
# Game 912: payoff = 0.0
# Game 913: payoff = 0.0
# Game 914: payoff = -1000.0
# Game 915: payoff = -1000.0
# Game 916: payoff = -1500.0
# Game 917: payoff = 0.0
# Game 918: payoff = -1000.0
# Game 919: payoff = -1000.0
# Game 920: payoff = 0.0
# Game 921: payoff = 0.0
# Game 922: payoff = 0.0
# Game 923: payoff = 0.0
# Game 924: payoff = -1000.0
# Game 925: payoff = -1000.0
# Game 926: payoff = -1000.0
# Game 927: payoff = 0.0
# Game 928: payoff = 0.0
# Game 929: payoff = 0.0
# Game 930: payoff = 0.0
# Game 931: payoff = 0.0
# Game 932: payoff = -1000.0
# Game 933: payoff = 0.0
# Game 934: payoff = 0.0
# Game 935: payoff = 0.0
# Game 936: payoff = -1000.0
# Game 937: payoff = 0.0
# Game 938: payoff = -1500.0
# Game 939: payoff = -1000.0
# Game 940: payoff = -1000.0
# Game 941: payoff = -1000.0
# Game 942: payoff = -7700.0
# Game 943: payoff = 0.0
# Game 944: payoff = -1000.0
# Game 945: payoff = -1000.0
# Game 946: payoff = 0.0
# Game 947: payoff = 0.0
# Game 948: payoff = -1000.0
# Game 949: payoff = -1000.0
# Game 950: payoff = 0.0
# Game 951: payoff = 0.0
# Game 952: payoff = 0.0
# Game 953: payoff = -1000.0
# Game 954: payoff = -2900.0
# Game 955: payoff = -1500.0
# Game 956: payoff = 0.0
# Game 957: payoff = -1000.0
# Game 958: payoff = 0.0
# Game 959: payoff = -1000.0
# Game 960: payoff = -1000.0
# Game 961: payoff = -1000.0
# Game 962: payoff = 0.0
# Game 963: payoff = 0.0
# Game 964: payoff = 0.0
# Game 965: payoff = -1000.0
# Game 966: payoff = 0.0
# Game 967: payoff = 0.0
# Game 968: payoff = 0.0
# Game 969: payoff = -1000.0
# Game 970: payoff = -300.0
# Game 971: payoff = 0.0
# Game 972: payoff = 1500.0
# Game 973: payoff = 0.0
# Game 974: payoff = -1000.0
# Game 975: payoff = -1000.0
# Game 976: payoff = 0.0
# Game 977: payoff = -1000.0
# Game 978: payoff = 0.0
# Game 979: payoff = 0.0
# Game 980: payoff = 0.0
# Game 981: payoff = -1000.0
# Game 982: payoff = -1500.0
# Game 983: payoff = -1000.0
# Game 984: payoff = -2900.0
# Game 985: payoff = -1500.0
# Game 986: payoff = -1000.0
# Game 987: payoff = 0.0
# Game 988: payoff = 0.0
# Game 989: payoff = -1500.0
# Game 990: payoff = -1000.0
# Game 991: payoff = 0.0
# Game 992: payoff = -1000.0
# Game 993: payoff = -2000.0
# Game 994: payoff = -1000.0
# Game 995: payoff = -1500.0
# Game 996: payoff = 0.0
# Game 997: payoff = 0.0
# Game 998: payoff = -1000.0
# Game 999: payoff = -1500.0
# Game 1000: payoff = 1500.0
#
# Average payoff over 1000 games: -563.80
